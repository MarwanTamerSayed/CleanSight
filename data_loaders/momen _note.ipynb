# %%
# !pip install pymupdf
# Out:
# ...
#    ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.2 MB ? eta -:--:--
#    - -------------------------------------- 0.8/19.2 MB 2.8 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/19.2 MB 2.0 MB/s eta 0:00:10
#    --- ------------------------------------ 1.6/19.2 MB 2.4 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.1/19.2 MB 2.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.9/19.2 MB 2.6 MB/s eta 0:00:07
#    ------- -------------------------------- 3.4/19.2 MB 2.6 MB/s eta 0:00:07
#    -------- ------------------------------- 3.9/19.2 MB 2.6 MB/s eta 0:00:06
#    --------- ------------------------------ 4.5/19.2 MB 2.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 5.0/19.2 MB 2.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.5/19.2 MB 2.7 MB/s eta 0:00:06
# ...

# %%
import fitz
from pathlib import Path
